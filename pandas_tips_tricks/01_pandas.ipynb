# %% [markdown]
# ## **Pandas Day-01**

# %%
# import libraries
import pandas as pd

# %%
# pandas version
print(pd.__version__)
# Out:
# 2.1.1

# %%
# load dataset
df = pd.read_csv('./Data/Pakistan-data.csv')
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %%
# data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
# data summary
df.describe()
# Out:
#        AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# count    528.000000       5.280000e+02  5.280000e+02    5.280000e+02
# mean    1492.005871       2.462780e+05  1.252757e+05    1.209841e+05
# std     2039.453778       2.711898e+05  1.375630e+05    1.337169e+05
# min        0.000000       0.000000e+00  0.000000e+00    0.000000e+00
# 25%      425.000000       5.093450e+04  2.712725e+04    2.397900e+04
# 50%      882.000000       1.652410e+05  8.413450e+04    8.204400e+04
# 75%     1734.250000       3.129112e+05  1.605022e+05    1.522190e+05
# max    18374.000000       2.297375e+06  1.172995e+06    1.124167e+06
#
#        TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# count           528.000000         528.000000                  528.000000
# mean             18.174242          98.982614                    6.277064
# std              25.522248          26.812660                    2.074947
# ...

# %%
# lets download the titanic dataset
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# load the dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## ***Basic Information***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# find missing values
df.isnull().sum() # count of missing values
df.isnull().sum() / len(df)*100 # percentage of missing values
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# visualize the missing values
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis') # for different color show
sns.heatmap(df.isnull()) # just simple map
# Out:
# <Axes: >

# %%
# unique values in a column
df['sex'].unique() # find unique values in a column
df['sex'].value_counts() # find how many categories with how many numbers in
df['sex'].value_counts() / len(df)*100 # calculate the % of each category numbers
df[['sex', 'class']].value_counts() # check two column together
# Out:
# sex     class
# male    Third     347
# female  Third     144
# male    First     122
#         Second    108
# female  First      94
#         Second     76
# Name: count, dtype: int64

# %%
# find a unique number of each column in a dataset
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
# how much fare for both sexes by using groupby function (one column)
df.groupby('sex')['fare'].mean()
df.groupby('class')['fare'].mean()
df.groupby('who')['fare'].mean()
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_4088\457227195.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('class')['fare'].mean()
# who
# child    32.785795
# man      24.864182
# woman    46.570711
# Name: fare, dtype: float64

# %%
# how much fare for both sexes by using groupby function (two columns)
df.groupby(['sex', 'class'])['fare'].mean()
df.groupby(['survived', 'sex', 'who'])['fare'].mean()
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_4088\3743805313.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['sex', 'class'])['fare'].mean()
# survived  sex     who
# 0         female  child    32.076113
#                   woman    20.967174
#           male    child    33.073905
#                   man      21.490736
# 1         female  child    30.887800
#                   woman    54.813801
#           male    child    35.562700
#                   man      42.076422
# Name: fare, dtype: float64

# %%
# calculate how many male, female, child in each class (number)
df.groupby(['survived', 'sex', 'who']).size()
# Out:
# survived  sex     who
# 0         female  child     15
#                   woman     66
#           male    child     19
#                   man      449
# 1         female  child     28
#                   woman    205
#           male    child     21
#                   man       88
# dtype: int64

# %%
# correlation matrix
correlation_df = df[['age', 'fare', 'sibsp', 'parch']].corr()

# %%
# show the heatmap
sns.heatmap(correlation_df, annot=True)
# Out:
# <Axes: >

# %%
# Pairplot
sns.pairplot(df)

# %% [markdown]
# ## ***Day-11***

# %% [markdown]
# ## ***Further Pandas tips & tricks***

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Missing values and imputing them

# %%
# find the percentage of the missing values in the dataset
df.isnull().sum() / len(df)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# 1- drop deck column from the dataset
df.drop('deck', axis=1, inplace=True)

# %%
# Mean, Median & Mode
print("Age mean:", df['age'].mean())
print("Age median:", df['age'].median())
print("Age Mode:", df['age'].mode(0))
print("Age mode:", df['age'].mode(1))
# Out:
# Age mean: 29.69911764705882
# Age median: 28.0
# Age Mode: 0   NaN
# Name: age, dtype: float64
# Age mode: 0    24.0
# Name: age, dtype: float64

# %%
# 2- fill the missing values in the age column by mean
df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
# fill embarked and embark_town with mode
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0], inplace=True)

# %%
# make heatmap to see the missing values
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# ## ***Binning***

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# find the min & max age of the passengers
print("Minimum age:", df.age.min())
print("Maximum age:", df.age.max())
# Out:
# Minimum age: 0.42
# Maximum age: 80.0

# %%
# make histplot of age column (it tells the data distribution)
sns.histplot(df, x = 'age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# create binnings of the age column
bins = [0,1,5,12,18,30,50,80]
labels = ['infants', 'Toddlers', 'kids', 'Teens', 'Young', 'Middle-age', 'Old']
pd.cut(df['age'], bins=bins, labels=labels)
# Out:
# 0           Young
# 1      Middle-age
# 2           Young
# 3      Middle-age
# 4      Middle-age
#           ...
# 886         Young
# 887         Young
# 888         Young
# 889         Young
# 890    Middle-age
# Name: age, Length: 891, dtype: category
# Categories (7, object): ['infants' < 'Toddlers' < 'kids' < 'Teens' < 'Young' < 'Middle-age' < 'Old']

# %% [markdown]
# ## ***Feature Engineering***

# %%
# create binnings of the age column
bins = [0,1,5,12,18,30,50,80]
labels = ['infants', 'Toddlers', 'kids', 'Teens', 'Young', 'Middle-age', 'Old']
df['bin_age'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone     bin_age
# 0    man        True  Southampton    no  False       Young
# 1  woman       False    Cherbourg   yes  False  Middle-age
# 2  woman       False  Southampton   yes   True       Young
# 3  woman       False  Southampton   yes  False  Middle-age
# 4    man        True  Southampton    no   True  Middle-age

# %%
# check how many individuals in each category
df['bin_age'].value_counts()
# Out:
# bin_age
# Young         447
# Middle-age    241
# Teens          70
# Old            64
# Toddlers       30
# kids           25
# infants        14
# Name: count, dtype: int64

# %%
# create a bins plot
sns.countplot(x='bin_age', data=df, palette=['green', 'red', 'purple', 'orange', 'blue', 'yellow'])
# set theme
sns.set_style('whitegrid')
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_4088\1040526529.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='bin_age', data=df, palette=['green', 'red', 'purple', 'orange', 'blue', 'yellow'])
# C:\Users\adnan\AppData\Local\Temp\ipykernel_4088\1040526529.py:2: UserWarning:
# The palette list has fewer values (6) than needed (7) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x='bin_age', data=df, palette=['green', 'red', 'purple', 'orange', 'blue', 'yellow'])

# %% [markdown]
# ## ***RENAME THE COLUMN NAME***

# %%
# Rename the column name
df.rename(columns={'bin_age':'age_groups'}, inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  age_groups
# 0    man        True  Southampton    no  False       Young
# 1  woman       False    Cherbourg   yes  False  Middle-age
# 2  woman       False  Southampton   yes   True       Young
# 3  woman       False  Southampton   yes  False  Middle-age
# 4    man        True  Southampton    no   True  Middle-age

# %% [markdown]
# ## ***DATA FILTERATION***

# %%
df_01 = df[['survived', 'age_groups', 'fare', 'class']]
df_01.head()
# Out:
#    survived  age_groups     fare  class
# 0         0       Young   7.2500  Third
# 1         1  Middle-age  71.2833  First
# 2         1       Young   7.9250  Third
# 3         1  Middle-age  53.1000  First
# 4         0  Middle-age   8.0500  Third

# %%
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
# filter the data based on row data
df_first = df_01[df_01['class'] == 'First']
df_first.head()
# Out:
#     survived  age_groups     fare  class
# 1          1  Middle-age  71.2833  First
# 3          1  Middle-age  53.1000  First
# 6          0         Old  51.8625  First
# 11         1         Old  26.5500  First
# 23         1       Young  35.5000  First

# %%
# select only those rows where people have paid more than 200 pounds
df_200 = df_01[df_01['fare'] > 200]

# %%
df_200.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 27 to 779
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   survived    20 non-null     int64
#  1   age_groups  20 non-null     category
#  2   fare        20 non-null     float64
#  3   class       20 non-null     category
# dtypes: category(2), float64(1), int64(1)
# memory usage: 1008.0 bytes

# %%
# check all were in which classes
df_200['class'].value_counts()
# Out:
# class
# First     20
# Second     0
# Third      0
# Name: count, dtype: int64

# %%
# how to add two filters
df_01[(df_01['fare'] > 70) & (df_01['class'] == 'First')]
# Out:
#      survived  age_groups      fare  class
# 1           1  Middle-age   71.2833  First
# 27          0       Young  263.0000  First
# 31          1       Young  146.5208  First
# 34          0       Young   82.1708  First
# 52          1  Middle-age   76.7292  First
# ..        ...         ...       ...    ...
# 829         1         Old   80.0000  First
# 835         1  Middle-age   83.1583  First
# 849         1       Young   89.1042  First
# 856         1  Middle-age  164.8667  First
# 879         1         Old   83.1583  First
#
# [100 rows x 4 columns]

# %% [markdown]
# ## ***Day-13***
#
# ## **Pakistan Population dataset**
# The data was collected from the following [link](https://www.kaggle.com/datasets/mabdullahsajid/population-of-pakistan-dataset):
#
# **Years of the data**
# 1. 2017
# 2. 1998

# %% [markdown]
# **Author Name:** Muhammad Adnan \
# **Email:** adnanagri12@gmail.com

# %% [markdown]
# About Dataset \
# `Description`
# This dataset contains demographic information from the Pakistan Population Census conducted in 2017. It provides detailed population data at various administrative levels within Pakistan, including provinces, divisions, districts, and sub-divisions. The dataset also includes information on urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from the 1998 census, and annual growth rates.
#
# `Features`
# Province: The administrative provinces or regions of Pakistan where the census data was collected.
#
# Division: The divisions within each province. Divisions are the second level of administrative divisions in Pakistan.
#
# District: Districts within each division, representing larger administrative units.
#
# Sub-Division: Sub-divisions or tehsils within each district, providing more localized data.
# Area: The land area (in square kilometers) of each sub-division.
#
# Urban Population 2017: The population of urban areas within each sub-division for the year 2017.
#
# Rural Population 2017: The population of rural areas within each sub-division for the year 2017.
#
# Male Population 2017: The male population within each sub-division for the year 2017.
#
# Female Population 2017: The female population within each sub-division for the year 2017.
#
# Transgender Population 2017: The population of transgender individuals within each sub-division for the year 2017.
#
# Sex Ratio 2017: The sex ratio, calculated as the number of females per 1000 males, within each sub-division for the year 2017.
#
# Population in 1998: The total population of each sub-division as recorded in the 1998 census.
#
# Annual Growth Rate: The annual growth rate of the population in each sub-division, calculated as the percentage increase from 1998 to 2017.
#
# `Data Source`
# The data in this dataset was collected from official Pakistan Population Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research.
#
# `Data Usage`
# Researchers and analysts can use this dataset to explore demographic trends, population growth, urbanization rates, gender distribution, and more within Pakistan at different administrative levels. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# ## Purpose of this analysis:
#
# we will fill this at the end or during the process of analysis.

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load dataset
df = pd.read_csv('../pandas_tips_tricks/Data/Pakistan-data.csv')
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  ...  POPULATION 1998 (RURAL)  \
# ...

# %% [markdown]
# ## ***1. Composition***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %%
# Show all the column
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
# print all columns
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# summary of the data
df.describe().T
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %%
# HOW MANY ARE THE MISSING VALUES
df.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %%
# boxplot
sns.histplot(df, x = 'AREA (sq.km)')
# Out:
# <Axes: xlabel='AREA (sq.km)', ylabel='Count'>

# %%
sns.boxplot(df, y = 'AREA (sq.km)')
# Out:
# <Axes: ylabel='AREA (sq.km)'>

# %%
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
sns.boxplot(df, x = 'DIVISION', y= 'ALL SEXES (RURAL)')
# Out:
# <Axes: xlabel='DIVISION', ylabel='ALL SEXES (RURAL)'>

# %%
# It is very hard to plot,therefore we will use groupby function to make tabulated data output
df['DIVISION'].nunique()
# Out:
# 28

# %%
df.groupby(['DIVISION']).size().sort_values()
# Out:
# DIVISION
# Badin Division                   5
# MARDAN DIVISION                  7
# SAHIWAL DIVISION                 7
# KOHAT DIVISION                  14
# MULTAN DIVISION                 14
# D.G.KHAN DIVISION               14
# HAZARA DIVISION                 15
# BAHAWALPUR DIVISION             15
# DERA ISMAIL KHAN DIVISION       15
# BANNU DIVISION                  15
# Shaheed Benazirabad Division    15
# SARGODHA DIVISION               17
# FAISALABAD DIVISION             17
# LAHORE DIVISION                 17
# Kalat Division                  18
# Sukkur Division                 18
# PESHAWAR DIVISION               18
# Mirpurkhas Division             18
# Naseerabad Division             19
# Zhob Division                   19
# GUJRANWALA DIVISION             20
# Larkana Division                21
# RAWALPINDI DIVISION             22
# Karachi Division                30
# Hyderabad Division              30
# MALAKAND DIVISION               33
# ...

# %%
# Calculate the mean of all sexes (rural) based on province
df.groupby('PROVINCE')['ALL SEXES (RURAL)'].mean()
# Out:
# PROVINCE
# BALOCHISTAN     67783.465649
# KPK            350603.380282
# KPK/FATA        99733.760870
# PUNJAB         480160.293706
# SINDH          167968.182482
# Name: ALL SEXES (RURAL), dtype: float64

# %%
# Calculate the mean of all sexes (rural) based on province, division, district, & sub division
df.groupby(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION'])['ALL SEXES (RURAL)'].mean()
# Out:
# PROVINCE     DIVISION                      DISTRICT                      SUB DIVISION
# BALOCHISTAN  Kalat Division                KALAT DISTRICT                GAZG SUB-TEHSIL                   5721.0
#                                                                          JOHAN SUB-TEHSIL                 10708.0
#                                                                          KALAT TEHSIL                     92298.0
#                                                                          MANGOCHAR TEHSIL                 65678.0
#                                                                          SURAB TEHSIL                    165260.0
#                                            KHUZDAR DISTRICT              ARANJI SUB-TEHSIL                42318.0
#                                                                          KARAKH SUB-TEHSIL                31016.0
# ...

# %%
df.groupby(['PROVINCE'])['POPULATION 1998 (RURAL)'].mean()
# Out:
# PROVINCE
# BALOCHISTAN     37944.450382
# KPK            209638.816901
# KPK/FATA        62657.086957
# PUNJAB         350172.034965
# SINDH          113796.167883
# Name: POPULATION 1998 (RURAL), dtype: float64

# %%
# how much rural population of pakistan in 1998 is
print("Rural Population in 1998 was:", df['POPULATION 1998 (RURAL)'].sum())
print("Urban population in 1998 was:", df['POPULATION 1998 (URBAN)'].sum())

# how much rural population of pakistan in 2017 is
print("Rural Population in 2017 was:", df['ALL SEXES (RURAL)'].sum())
print("Urban Population in 2017 was:", df['ALL SEXES (URBAN)'].sum())
# Out:
# Rural Population in 1998 was: 88401981
# Urban population in 1998 was: 42316331
# Rural Population in 2017 was: 130034790
# Urban Population in 2017 was: 74375943

# %%
# HOW much the rural and urban population was increased from 1998 - 2017?
pop_rural_1998 = df['POPULATION 1998 (RURAL)'].sum()
pop_rural_2017 = df['ALL SEXES (RURAL)'].sum()

# How much the urban population was increased?
pop_urban_1998 = df['POPULATION 1998 (URBAN)'].sum()
pop_urban_2017 = df['ALL SEXES (URBAN)'].sum()

# Print the difference in rural and urban
pop_rural_increased = pop_rural_2017 - pop_rural_1998
print("Increased rural population from 1998 - 2017 is:", pop_rural_increased)

# print the difference in urban
pop_urban_increased = pop_urban_2017 - pop_urban_1998
print("Increased urban population from 1998 - 2017 is:", pop_urban_increased)

# print the total population (Urban and rural)
print("Total population was increased from 1998 -2017:", pop_rural_increased + pop_urban_increased)
# Out:
# Increased rural population from 1998 - 2017 is: 41632809
# Increased urban population from 1998 - 2017 is: 32059612
# Total population was increased from 1998 -2017: 73692421

# %% [markdown]
# ## Assignment: How to combine 3 columns in one column? make a separate data of everything based on Sex (Male, Female & Transgender)

# %%
df.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
# Combine the three columns into a new column
df['combined'] = df['MALE (URBAN)'] + df['FEMALE (URBAN)'].astype(int) + df['TRANSGENDER (URBAN)']
df.head()
# Out:
#   PROVINCE             DIVISION               DISTRICT         SUB DIVISION  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT  BAHAWALNAGAR TEHSIL
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT     CHISHTIAN TEHSIL
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    FORT ABBAS TEHSIL
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT    HAROONABAD TEHSIL
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT   MINCHINABAD TEHSIL
#
#    AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  FEMALE (RURAL)  \
# 0        1729.0             619550        316864          302644
# 1        1500.0             540342        273788          266500
# 2        2536.0             361240        182655          178541
# 3        1295.0             382115        192278          189808
# 4        1818.0             452723        231506          221178
#
#    TRANSGENDER (RURAL)  SEX RATIO (RURAL)  AVG HOUSEHOLD SIZE (RURAL)  \
# ...

# %%
df_gender = df[['MALE (RURAL)','MALE (URBAN)', 'FEMALE (RURAL)','FEMALE (URBAN)','TRANSGENDER (RURAL)','TRANSGENDER (URBAN)']]
df_gender.head()
# Out:
#    MALE (RURAL)  MALE (URBAN)  FEMALE (RURAL)  FEMALE (URBAN)  \
# 0        316864         98391          302644           95402
# 1        273788         75546          266500           73851
# 2        182655         31360          178541           30150
# 3        192278         71345          189808           71236
# 4        231506         36694          221178           35590
#
#    TRANSGENDER (RURAL)  TRANSGENDER (URBAN)
# 0                   42                   47
# 1                   54                   27
# 2                   44                   18
# 3                   29                   19
# 4                   39                   10

# %%
df_sex = pd.DataFrame (df_gender)
# Use the melt function to reshape the data
melted_df = pd.melt(df_sex, var_name='sex', value_name='value')
# Display the reshaped DataFrame
print(melted_df)
# Out:
#                       sex    value
# 0            MALE (RURAL)   316864
# 1            MALE (RURAL)   273788
# 2            MALE (RURAL)   182655
# 3            MALE (RURAL)   192278
# 4            MALE (RURAL)   231506
# 5            MALE (RURAL)   461525
# 6            MALE (RURAL)        0
# 7            MALE (RURAL)   239541
# 8            MALE (RURAL)   171117
# 9            MALE (RURAL)   112952
# 10           MALE (RURAL)   288761
# 11           MALE (RURAL)   382228
# 12           MALE (RURAL)   500742
# 13           MALE (RURAL)   536887
# 14           MALE (RURAL)   516640
# 15           MALE (RURAL)   109429
# 16           MALE (RURAL)   410429
# 17           MALE (RURAL)   353638
# 18           MALE (RURAL)   300077
# 19           MALE (RURAL)   104011
# 20           MALE (RURAL)   398960
# 21           MALE (RURAL)   307377
# 22           MALE (RURAL)   285241
# 23           MALE (RURAL)   560409
# 24           MALE (RURAL)   711866
# 25           MALE (RURAL)    18280
# ...

# %%
melted_df.shape
# Out:
# (3168, 2)

# %%
import plotly.express as px

# Calculate the mean values for 'value' by 'sex'
mean_values = melted_df.groupby('sex')['value'].mean().reset_index()

# Create a bar plot using Plotly Express
fig = px.bar(mean_values, x="sex", y="value", color ='sex', color_discrete_sequence=['#03fc7f', '#fc0373', '#fcba03', '#03dbfc', '#9d03fc', '#0373fc'])

# Customize the bar width if needed
fig.update_traces(marker=dict(line=dict(width=2)))
# bar width size
fig.update_traces(width=0.7)
# graph width and height
fig.update_layout(width=800, height=600)
# x axis ticks in the 90 degree angle
fig.update_layout(xaxis_tickangle=-90)
# Update the text values to display only 2 decimal places
fig.update_traces(texttemplate='%{y:.2f}', textposition='outside')
# Show the plot
fig.show()

# %% [markdown]
# ### ***Interpretation***
# The bar graph above provides a clear indication that there is a significantly higher gender population in rural areas when compared to urban areas, regardless of gender identity. It is evident that individuals in rural regions tend to have less formal education and typically have larger families than their urban counterparts.
